# %% [markdown]
# ### grp

# %% [markdown]
# ## Hands-On Machine Learning with Scikit-Learn & TensorFlow

# %% [markdown]
# ## CHAPTER 10: Introduction to Artificial Neural Networks

# %% [markdown]
# ### Artificial Neural Networks [ANNs]:
# -  emulates the brain's architecture for building artificial intelligence machines
# -  examples:
#     -  classifying billions of images
#     -  speech recognition services
#     -  user recommnedation systems

# %% [markdown]
# ### Deep Neural Network [DNNs]:
# -  when an ANN contains 2 or more hidden layers

# %% [markdown]
# ### Why use ANNs / DNNs?:
# -  large volumes of data available to train neural networks
# -  ANNs outperform ML techniques on very large and complex datasets
# -  powerful GPUs available for faster computing power

# %% [markdown]
# ### Biological Neurons:
# -  found in animal cerebral cortexes
# -  contains a nucleas and branching extensions called **_dendrites_** and **_axon_**
# -  **_axon_** splits into many branches called **_telodendria_** with **_synaptic terminals_ [_synapses_]** (connected to the **_dendrites_**) at the end tip
# -  biological neurons receive short electrical impulses called **_signals_** from other neurons via **_synapses_**
# -  neurons fire its own signals when it receives many signals from other neurons

# %% [markdown]
# ### Artificial Neurons:
# -  contains 1 or more **binary** (on/off) inputs and one binary output
# -  it activates its output when a certain number of its inputs are active
#
# #### Scenarios [page 259]
# -  The first network on the left is simply the identity function: if neuron A is activa‐ ted, then neuron C gets activated as well (since it receives two input signals from neuron A), but if neuron A is off, then neuron C is off as well.
# -  The second network performs a logical AND: neuron C is activated only when both neurons A and B are activated (a single input signal is not enough to acti‐ vate neuron C).
# -  The third network performs a logical OR: neuron C gets activated if either neu‐ ron A or neuron B is activated (or both).
# -  Finally, if we suppose that an input connection can inhibit the neuron’s activity (which is the case with biological neurons), then the fourth network computes a slightly more complex logical proposition: neuron C is activated only if neuron A is active and if neuron B is off. If neuron A is active all the time, then you get a logical NOT: neuron C is active when neuron B is off, and vice versa.

# %% [markdown]
# ## Perceptron:
# -  based on **Linear Threshold Unit** (LTU):
#     1.  inputs and output are numbers [instead of binary on/off values] + each input associated with a weight
#     2.  computes a weighted sum of its inputs (z = w1 * x1 + w2 * x2 + ... + wn * xn = wT * x)
#     3.  applies a _step function_ (ex: **heaviside step function**) to step 2 sum
#     4.  outputs result

# %% [markdown]
# -  composed of a single layer of LTUs with each neuron connected (**inputs neurons**) to all the inputs
# -  __input neurons__ => output whatever input they are fed
# -  __bias neurons__ => output 1 all the time
# -  predictions are based on hard threshold ***perceptrons do not output a class probability like LR***
# -  ML Model Example:
#     -  Linear Binary Classification => if results exceed LTU calculated threshold then label positive class else label negative class
# -  **Multi-Layer Perceptron** (MLP):
#     -  stacks multiple perceptrons
#     -  composed of ... :
#         -  one input layer (_contains a bias neuron_)
#         -  one or more LTU layers aka **hidden layers** (_contains a bias neuron_)
#         -  one final LTU layer aka **output layer** (_does **NOT** contains a bias neuron_)

# %% [markdown]
# ### How are Perceptrons Trained?:
# -  https://en.wikipedia.org/wiki/Hebbian_theory:
#     -  connection weight between 2 neurons is increased whenever they have the same output
# -  takes into account error made by the network
# -  is fed one training instance at a time and makes its predictions for each instance
# -  every output neuron that makes a wrong prediction reinforces the connection weights from the inputs that would have contributed to the correct prediction

# %% [markdown]
# ## Backpropagation:
# -  article => https://scholar.google.com/scholar?q=Learning+Internal+Representations+by+Error+Propagation
# -  innovative method to successfully train MLPs
# -  hybrid method using Gradient Descent using reverse-mode autodiff
# -  popular activation functions:
#     -  hyperbolic tangent function tanh
#     -  ReLU

# %% [markdown]
# _technical summary under the hood => **backpropagation**_ ...
#
# **For each training instance, the algorithm feeds it to the network and computes the output of every neuron in each consecutive layer (this is the forward pass, just like when making predictions). Then it measures the network’s output error (i.e., the dif‐ ference between the desired output and the actual output of the network), and it computes how much each neuron in the last hidden layer contributed to each output neuron’s error. It then proceeds to measure how much of these error contributions came from each neuron in the previous hidden layer—and so on until the algorithm reaches the input layer. This reverse pass efficiently measures the error gradient across all the connection weights in the network by propagating the error gradient backward in the network (hence the name of the algorithm). If you check out the reverse-mode autodiff algorithm in Appendix D, you will find that the forward and reverse passes of backpropagation simply perform reverse-mode autodiff. The last step of the backpropagation algorithm is a Gradient Descent step on all the connec‐ tion weights in the network, using the error gradients measured earlier.** - Aurelien Geron [Hands on ML w SKLearn & TF]

# %% [markdown]
# ### high level steps:
# 1.  make a prediction (**forward pass**) for each training instance
# 2.  measures error
# 3.  goes through each layer in reverse to measure error contribution from each connection (**reverse pass**)
# 4.  slightly tweaks connection weights to reduce error (**gradient descent**)
#
# https://en.wikipedia.org/wiki/Backpropagation
#
# https://stackoverflow.com/questions/4752626/epoch-vs-iteration-when-training-neural-networks

# %% [markdown]
# ## Neural Network Hyperparameters:
# -  neural networks are difficult to tune because they are so flexible and have many hyperparameters to tweak
# -  flexible volatile options ... :
#     -  number of layers
#     -  number of neurons per layer
#     -  type of activation function use in each layer
#     -  weight initialization logic
#     -  etc ...
# -  solutions include ... :
#     -  grid search w/ cross validation [_not recommended w/ large datasets because too time consuming_]
#     -  **randomized search**

# %% [markdown]
# ### Reusing Neural Networks:
# -  reuse lower layers of the first network
# -  network will not have to learn all the low-level structures from scratch that occur in most datasets (ex: pictures)
# -  network will only have to learn the higher-level structures (ex: different objects in pictures)
# -  scenario ... :
#     -  large image classification / speech recognition require networks with dozen of layers + huge training set
#     -  usually not needed to train these large models from scratch hence reuse parts of pretrained state of the art network learning from a similar use case

# %% [markdown]
# ### Neural Network Best Practices:
# -  many problems can start with just 1 or 2 hiddren layers
# -  complex problems can require gradually increasing number of hidden layers when training set starts to overfit
# -  try gradually increasing the number of neurons until the network starts to overfit the training set
# -  recommended to increase number of layers over increasing number of neurons per layer
# -  tweaking number of neurons still considered a challenge (**no best practice ... yet**)
# -  try **early stopping** to prevent overfitting
# -  ReLU is a good choice for activation function
# -  softmax activation function for output layer is a good choice for classification (multi class)
# -  logistic activation function for output layer is a good choice for classification (binary)

# %% [markdown]
# ## _Exercises_

# %%
import tensorflow as tf
print(tf.__version__)

import sklearn
print(sklearn.__version__)
# Out:
# 1.13.1
# 0.20.0

# %% [markdown]
# ### sklearn ltu network:
# -  perceptron learning algorithm strongly resembles Stochastic Gradient Descent
# -  equivalent to sklearn SDGClassifier w/ following hyperparameters set:
#     -  loss = "perceptron"
#     -  learning_rate = "constant"
#     -  eta [learning rate] = 1
#     -  penalty = None (no regularization)

# %%
import numpy as np
from sklearn.datasets import load_iris
from sklearn.linear_model import Perceptron

iris = load_iris()
X = iris.data[:, (2, 3)]  # petal length, petal width
y = (iris.target == 0).astype(np.int) # iris setosa?

per_clf = Perceptron(max_iter=100, tol=-np.infty, random_state=42)
per_clf.fit(X, y)

y_pred = per_clf.predict([[2, 0.5]])

# %% [markdown]
# ### tf mlp dnn classifier via high level tf.learn api:
# -  model trains dnn classification w/ 2 hidden layers [300 neurons, 100 neurons]
# -  softmax output layer w/ 10 neurons
# -  run 40 epochs using batches of 50 instances
# -  **DNNClassifier** class creates all neuron layers based on ReLU activation function

# %%
# keras mnist dataset load
(X_train, y_train), (X_test, y_test) = tf.keras.datasets.mnist.load_data()
X_train = X_train.astype(np.float32).reshape(-1, 28*28) / 255.0
X_test = X_test.astype(np.float32).reshape(-1, 28*28) / 255.0
y_train = y_train.astype(np.int32)
y_test = y_test.astype(np.int32)
X_valid, X_train = X_train[:5000], X_train[5000:]
y_valid, y_train = y_train[:5000], y_train[5000:]
print(X_train.shape)
print(X_valid.shape)
print(X_test.shape)
# Out:
# (55000, 784)
# (5000, 784)
# (10000, 784)

# %%
feature_cols = [tf.feature_column.numeric_column("X", shape=[28 * 28])]
dnn_clf = tf.estimator.DNNClassifier(hidden_units=[300,100], n_classes=10,
                                     feature_columns=feature_cols)

input_fn = tf.estimator.inputs.numpy_input_fn(
    x={"X": X_train}, y=y_train, num_epochs=40, batch_size=50, shuffle=True)
dnn_clf.train(input_fn=input_fn)
# Out:
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: /var/folders/1p/9j4_29dj62jf1c6tc1qqmk140000gn/T/tmpbvepjwbn
# INFO:tensorflow:Using config: {'_model_dir': '/var/folders/1p/9j4_29dj62jf1c6tc1qqmk140000gn/T/tmpbvepjwbn', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x126ca55c0>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# WARNING:tensorflow:From /anaconda3/lib/python3.6/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /anaconda3/lib/python3.6/site-packages/tensorflow_estimator/python/estimator/inputs/queues/feeding_queue_runner.py:62: QueueRunner.__init__ (from tensorflow.python.training.queue_runner_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# To construct input pipelines, use the `tf.data` module.
# WARNING:tensorflow:From /anaconda3/lib/python3.6/site-packages/tensorflow_estimator/python/estimator/inputs/queues/feeding_functions.py:500: add_queue_runner (from tensorflow.python.training.queue_runner_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# To construct input pipelines, use the `tf.data` module.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:From /anaconda3/lib/python3.6/site-packages/tensorflow/python/feature_column/feature_column_v2.py:2703: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# WARNING:tensorflow:From /anaconda3/lib/python3.6/site-packages/tensorflow/python/training/monitored_session.py:809: start_queue_runners (from tensorflow.python.training.queue_runner_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# To construct input pipelines, use the `tf.data` module.
# INFO:tensorflow:Saving checkpoints for 0 into /var/folders/1p/9j4_29dj62jf1c6tc1qqmk140000gn/T/tmpbvepjwbn/model.ckpt.
# INFO:tensorflow:loss = 118.851204, step = 1
# INFO:tensorflow:global_step/sec: 360.345
# INFO:tensorflow:loss = 13.5676565, step = 101 (0.278 sec)
# INFO:tensorflow:global_step/sec: 490.332
# INFO:tensorflow:loss = 13.941303, step = 201 (0.204 sec)
# INFO:tensorflow:global_step/sec: 396.088
# INFO:tensorflow:loss = 14.380838, step = 301 (0.253 sec)
# INFO:tensorflow:global_step/sec: 449.942
# INFO:tensorflow:loss = 18.2533, step = 401 (0.222 sec)
# INFO:tensorflow:global_step/sec: 467.468
# INFO:tensorflow:loss = 24.391632, step = 501 (0.214 sec)
# INFO:tensorflow:global_step/sec: 387.746
# INFO:tensorflow:loss = 7.8497643, step = 601 (0.260 sec)
# INFO:tensorflow:global_step/sec: 459.529
# INFO:tensorflow:loss = 23.055878, step = 701 (0.216 sec)
# INFO:tensorflow:global_step/sec: 494.288
# INFO:tensorflow:loss = 5.7487664, step = 801 (0.202 sec)
# INFO:tensorflow:global_step/sec: 466.801
# INFO:tensorflow:loss = 10.465647, step = 901 (0.215 sec)
# INFO:tensorflow:global_step/sec: 381.32
# INFO:tensorflow:loss = 7.49679, step = 1001 (0.262 sec)
# INFO:tensorflow:global_step/sec: 360.813
# INFO:tensorflow:loss = 4.356595, step = 1101 (0.278 sec)
# INFO:tensorflow:global_step/sec: 411.483
# INFO:tensorflow:loss = 11.125579, step = 1201 (0.242 sec)
# INFO:tensorflow:global_step/sec: 439.263
# INFO:tensorflow:loss = 1.6778429, step = 1301 (0.228 sec)
# INFO:tensorflow:global_step/sec: 370.924
# INFO:tensorflow:loss = 2.3794098, step = 1401 (0.270 sec)
# INFO:tensorflow:global_step/sec: 457.572
# INFO:tensorflow:loss = 2.3900044, step = 1501 (0.218 sec)
# INFO:tensorflow:global_step/sec: 452.259
# INFO:tensorflow:loss = 1.627016, step = 1601 (0.221 sec)
# INFO:tensorflow:global_step/sec: 431.406
# INFO:tensorflow:loss = 5.406056, step = 1701 (0.232 sec)
# INFO:tensorflow:global_step/sec: 484.231
# INFO:tensorflow:loss = 6.4872537, step = 1801 (0.207 sec)
# INFO:tensorflow:global_step/sec: 461.781
# INFO:tensorflow:loss = 3.8940804, step = 1901 (0.216 sec)
# INFO:tensorflow:global_step/sec: 427.36
# INFO:tensorflow:loss = 2.872781, step = 2001 (0.234 sec)
# INFO:tensorflow:global_step/sec: 481.447
# INFO:tensorflow:loss = 4.1872077, step = 2101 (0.208 sec)
# INFO:tensorflow:global_step/sec: 456.109
# INFO:tensorflow:loss = 3.7620134, step = 2201 (0.220 sec)
# INFO:tensorflow:global_step/sec: 362.925
# INFO:tensorflow:loss = 0.67165357, step = 2301 (0.276 sec)
# INFO:tensorflow:global_step/sec: 457.084
# INFO:tensorflow:loss = 3.1019812, step = 2401 (0.219 sec)
# INFO:tensorflow:global_step/sec: 433.739
# INFO:tensorflow:loss = 1.9771504, step = 2501 (0.231 sec)
# INFO:tensorflow:global_step/sec: 401.294
# INFO:tensorflow:loss = 0.9101065, step = 2601 (0.249 sec)
# INFO:tensorflow:global_step/sec: 473.519
# INFO:tensorflow:loss = 0.2192318, step = 2701 (0.211 sec)
# INFO:tensorflow:global_step/sec: 489.307
# INFO:tensorflow:loss = 2.504853, step = 2801 (0.204 sec)
# INFO:tensorflow:global_step/sec: 473.803
# INFO:tensorflow:loss = 1.6954244, step = 2901 (0.211 sec)
# INFO:tensorflow:global_step/sec: 458.554
# INFO:tensorflow:loss = 5.593711, step = 3001 (0.218 sec)
# INFO:tensorflow:global_step/sec: 417.326
# INFO:tensorflow:loss = 0.96588415, step = 3101 (0.240 sec)
# INFO:tensorflow:global_step/sec: 487.667
# INFO:tensorflow:loss = 1.2877983, step = 3201 (0.205 sec)
# INFO:tensorflow:global_step/sec: 487.728
# INFO:tensorflow:loss = 0.29297894, step = 3301 (0.205 sec)
# INFO:tensorflow:global_step/sec: 464.656
# INFO:tensorflow:loss = 4.2825065, step = 3401 (0.215 sec)
# INFO:tensorflow:global_step/sec: 453.947
# INFO:tensorflow:loss = 1.2222984, step = 3501 (0.222 sec)
# INFO:tensorflow:global_step/sec: 425.958
# INFO:tensorflow:loss = 1.5356914, step = 3601 (0.234 sec)
# INFO:tensorflow:global_step/sec: 482.833
# INFO:tensorflow:loss = 3.2233086, step = 3701 (0.207 sec)
# INFO:tensorflow:global_step/sec: 458.47
# INFO:tensorflow:loss = 4.4384522, step = 3801 (0.218 sec)
# INFO:tensorflow:global_step/sec: 461.074
# INFO:tensorflow:loss = 9.619713, step = 3901 (0.216 sec)
# INFO:tensorflow:global_step/sec: 491
# INFO:tensorflow:loss = 3.6854327, step = 4001 (0.204 sec)
# INFO:tensorflow:global_step/sec: 487.244
# INFO:tensorflow:loss = 3.897298, step = 4101 (0.205 sec)
# INFO:tensorflow:global_step/sec: 483.251
# INFO:tensorflow:loss = 0.52360094, step = 4201 (0.207 sec)
# INFO:tensorflow:global_step/sec: 489.426
# INFO:tensorflow:loss = 0.5115167, step = 4301 (0.204 sec)
# INFO:tensorflow:global_step/sec: 446.412
# INFO:tensorflow:loss = 0.34204558, step = 4401 (0.224 sec)
# INFO:tensorflow:global_step/sec: 490.355
# INFO:tensorflow:loss = 7.170253, step = 4501 (0.204 sec)
# INFO:tensorflow:global_step/sec: 494.027
# INFO:tensorflow:loss = 0.3115476, step = 4601 (0.203 sec)
# INFO:tensorflow:global_step/sec: 482.137
# INFO:tensorflow:loss = 1.8192234, step = 4701 (0.208 sec)
# INFO:tensorflow:global_step/sec: 464.5
# INFO:tensorflow:loss = 0.267054, step = 4801 (0.215 sec)
# INFO:tensorflow:global_step/sec: 489.047
# INFO:tensorflow:loss = 1.4859599, step = 4901 (0.204 sec)
# INFO:tensorflow:global_step/sec: 421.921
# INFO:tensorflow:loss = 2.154349, step = 5001 (0.237 sec)
# INFO:tensorflow:global_step/sec: 449.598
# INFO:tensorflow:loss = 0.42186654, step = 5101 (0.223 sec)
# INFO:tensorflow:global_step/sec: 466.264
# INFO:tensorflow:loss = 2.1866791, step = 5201 (0.214 sec)
# INFO:tensorflow:global_step/sec: 468.656
# INFO:tensorflow:loss = 1.7512442, step = 5301 (0.213 sec)
# INFO:tensorflow:global_step/sec: 468.509
# INFO:tensorflow:loss = 0.9880459, step = 5401 (0.213 sec)
# INFO:tensorflow:global_step/sec: 492.514
# INFO:tensorflow:loss = 1.7908235, step = 5501 (0.203 sec)
# INFO:tensorflow:global_step/sec: 492.114
# INFO:tensorflow:loss = 2.4486098, step = 5601 (0.204 sec)
# INFO:tensorflow:global_step/sec: 485.151
# INFO:tensorflow:loss = 0.44385594, step = 5701 (0.206 sec)
# INFO:tensorflow:global_step/sec: 403.39
# INFO:tensorflow:loss = 0.23869362, step = 5801 (0.248 sec)
# INFO:tensorflow:global_step/sec: 478.174
# INFO:tensorflow:loss = 1.6547506, step = 5901 (0.209 sec)
# INFO:tensorflow:global_step/sec: 486.748
# INFO:tensorflow:loss = 2.2692287, step = 6001 (0.205 sec)
# INFO:tensorflow:global_step/sec: 453.539
# INFO:tensorflow:loss = 1.480107, step = 6101 (0.221 sec)
# INFO:tensorflow:global_step/sec: 472.847
# INFO:tensorflow:loss = 1.0975902, step = 6201 (0.212 sec)
# INFO:tensorflow:global_step/sec: 477.423
# INFO:tensorflow:loss = 1.6957027, step = 6301 (0.209 sec)
# INFO:tensorflow:global_step/sec: 475.57
# INFO:tensorflow:loss = 0.1290372, step = 6401 (0.210 sec)
# INFO:tensorflow:global_step/sec: 480.875
# INFO:tensorflow:loss = 0.2695741, step = 6501 (0.208 sec)
# INFO:tensorflow:global_step/sec: 475.22
# INFO:tensorflow:loss = 0.19147256, step = 6601 (0.211 sec)
# INFO:tensorflow:global_step/sec: 472.027
# INFO:tensorflow:loss = 0.049351644, step = 6701 (0.212 sec)
# INFO:tensorflow:global_step/sec: 476.78
# INFO:tensorflow:loss = 0.7254759, step = 6801 (0.210 sec)
# INFO:tensorflow:global_step/sec: 487.641
# INFO:tensorflow:loss = 2.7341528, step = 6901 (0.205 sec)
# INFO:tensorflow:global_step/sec: 498.179
# INFO:tensorflow:loss = 0.24026479, step = 7001 (0.201 sec)
# INFO:tensorflow:global_step/sec: 461.108
# INFO:tensorflow:loss = 0.026608005, step = 7101 (0.217 sec)
# INFO:tensorflow:global_step/sec: 459.62
# INFO:tensorflow:loss = 2.3930912, step = 7201 (0.218 sec)
# INFO:tensorflow:global_step/sec: 449.452
# INFO:tensorflow:loss = 1.0601045, step = 7301 (0.222 sec)
# INFO:tensorflow:global_step/sec: 474.939
# INFO:tensorflow:loss = 1.277735, step = 7401 (0.210 sec)
# INFO:tensorflow:global_step/sec: 465.779
# INFO:tensorflow:loss = 0.2656186, step = 7501 (0.215 sec)
# INFO:tensorflow:global_step/sec: 466.216
# INFO:tensorflow:loss = 0.33693248, step = 7601 (0.214 sec)
# INFO:tensorflow:global_step/sec: 426.292
# INFO:tensorflow:loss = 2.8304448, step = 7701 (0.235 sec)
# INFO:tensorflow:global_step/sec: 405.052
# INFO:tensorflow:loss = 0.0951146, step = 7801 (0.247 sec)
# INFO:tensorflow:global_step/sec: 456.736
# INFO:tensorflow:loss = 0.101788, step = 7901 (0.219 sec)
# INFO:tensorflow:global_step/sec: 374.936
# INFO:tensorflow:loss = 0.715709, step = 8001 (0.267 sec)
# INFO:tensorflow:global_step/sec: 398.411
# INFO:tensorflow:loss = 0.11883282, step = 8101 (0.250 sec)
# INFO:tensorflow:global_step/sec: 482.318
# INFO:tensorflow:loss = 3.822032, step = 8201 (0.208 sec)
# INFO:tensorflow:global_step/sec: 446.532
# INFO:tensorflow:loss = 0.31031936, step = 8301 (0.225 sec)
# INFO:tensorflow:global_step/sec: 398.25
# INFO:tensorflow:loss = 6.8184924, step = 8401 (0.250 sec)
# INFO:tensorflow:global_step/sec: 466.834
# INFO:tensorflow:loss = 0.7639016, step = 8501 (0.214 sec)
# INFO:tensorflow:global_step/sec: 495.668
# INFO:tensorflow:loss = 10.900278, step = 8601 (0.202 sec)
# INFO:tensorflow:global_step/sec: 438.658
# INFO:tensorflow:loss = 0.48061827, step = 8701 (0.229 sec)
# INFO:tensorflow:global_step/sec: 422.808
# INFO:tensorflow:loss = 0.1627387, step = 8801 (0.236 sec)
# INFO:tensorflow:global_step/sec: 374.929
# INFO:tensorflow:loss = 0.017293755, step = 8901 (0.268 sec)
# INFO:tensorflow:global_step/sec: 441.524
# INFO:tensorflow:loss = 0.07046393, step = 9001 (0.225 sec)
# INFO:tensorflow:global_step/sec: 459.387
# INFO:tensorflow:loss = 0.75809324, step = 9101 (0.218 sec)
# INFO:tensorflow:global_step/sec: 457.223
# INFO:tensorflow:loss = 0.18962735, step = 9201 (0.219 sec)
# INFO:tensorflow:global_step/sec: 395.241
# INFO:tensorflow:loss = 0.08856447, step = 9301 (0.253 sec)
# INFO:tensorflow:global_step/sec: 431.124
# INFO:tensorflow:loss = 2.46748, step = 9401 (0.232 sec)
# INFO:tensorflow:global_step/sec: 415.55
# INFO:tensorflow:loss = 0.42631918, step = 9501 (0.241 sec)
# INFO:tensorflow:global_step/sec: 448.278
# INFO:tensorflow:loss = 0.2296192, step = 9601 (0.223 sec)
# INFO:tensorflow:global_step/sec: 469.806
# INFO:tensorflow:loss = 0.0462632, step = 9701 (0.213 sec)
# INFO:tensorflow:global_step/sec: 475.907
# INFO:tensorflow:loss = 0.1515661, step = 9801 (0.210 sec)
# INFO:tensorflow:global_step/sec: 456.959
# INFO:tensorflow:loss = 0.9320079, step = 9901 (0.219 sec)
# INFO:tensorflow:global_step/sec: 390.129
# INFO:tensorflow:loss = 0.17608756, step = 10001 (0.256 sec)
# INFO:tensorflow:global_step/sec: 465.018
# INFO:tensorflow:loss = 1.0727407, step = 10101 (0.215 sec)
# INFO:tensorflow:global_step/sec: 472.148
# INFO:tensorflow:loss = 0.06908088, step = 10201 (0.212 sec)
# INFO:tensorflow:global_step/sec: 461.193
# INFO:tensorflow:loss = 0.17729667, step = 10301 (0.218 sec)
# INFO:tensorflow:global_step/sec: 429.351
# INFO:tensorflow:loss = 0.2303772, step = 10401 (0.232 sec)
# INFO:tensorflow:global_step/sec: 409.937
# INFO:tensorflow:loss = 0.3185804, step = 10501 (0.244 sec)
# INFO:tensorflow:global_step/sec: 437.386
# INFO:tensorflow:loss = 0.050760217, step = 10601 (0.228 sec)
# INFO:tensorflow:global_step/sec: 465.489
# INFO:tensorflow:loss = 0.6829896, step = 10701 (0.215 sec)
# INFO:tensorflow:global_step/sec: 456.853
# INFO:tensorflow:loss = 0.67100614, step = 10801 (0.219 sec)
# INFO:tensorflow:global_step/sec: 459.793
# INFO:tensorflow:loss = 0.12090798, step = 10901 (0.218 sec)
# INFO:tensorflow:global_step/sec: 392.405
# INFO:tensorflow:loss = 0.20680252, step = 11001 (0.255 sec)
# INFO:tensorflow:global_step/sec: 470.129
# INFO:tensorflow:loss = 0.023728466, step = 11101 (0.213 sec)
# INFO:tensorflow:global_step/sec: 455.961
# INFO:tensorflow:loss = 1.0998968, step = 11201 (0.219 sec)
# INFO:tensorflow:global_step/sec: 380.351
# INFO:tensorflow:loss = 0.057028256, step = 11301 (0.263 sec)
# INFO:tensorflow:global_step/sec: 451.808
# INFO:tensorflow:loss = 0.7685608, step = 11401 (0.221 sec)
# INFO:tensorflow:global_step/sec: 380.958
# INFO:tensorflow:loss = 0.118710555, step = 11501 (0.263 sec)
# INFO:tensorflow:global_step/sec: 458.478
# INFO:tensorflow:loss = 0.41088146, step = 11601 (0.217 sec)
# INFO:tensorflow:global_step/sec: 377.956
# INFO:tensorflow:loss = 0.26793244, step = 11701 (0.265 sec)
# INFO:tensorflow:global_step/sec: 388.369
# INFO:tensorflow:loss = 0.12704927, step = 11801 (0.259 sec)
# INFO:tensorflow:global_step/sec: 371.179
# INFO:tensorflow:loss = 0.73691064, step = 11901 (0.268 sec)
# INFO:tensorflow:global_step/sec: 388.933
# INFO:tensorflow:loss = 0.13470109, step = 12001 (0.257 sec)
# INFO:tensorflow:global_step/sec: 410.639
# INFO:tensorflow:loss = 0.19594216, step = 12101 (0.244 sec)
# INFO:tensorflow:global_step/sec: 379.438
# INFO:tensorflow:loss = 0.13724169, step = 12201 (0.263 sec)
# INFO:tensorflow:global_step/sec: 382.654
# INFO:tensorflow:loss = 1.363428, step = 12301 (0.262 sec)
# INFO:tensorflow:global_step/sec: 390.74
# INFO:tensorflow:loss = 0.06424802, step = 12401 (0.255 sec)
# INFO:tensorflow:global_step/sec: 379.115
# INFO:tensorflow:loss = 0.020774195, step = 12501 (0.264 sec)
# INFO:tensorflow:global_step/sec: 365.911
# INFO:tensorflow:loss = 0.24385816, step = 12601 (0.274 sec)
# INFO:tensorflow:global_step/sec: 344.576
# INFO:tensorflow:loss = 0.4185575, step = 12701 (0.289 sec)
# INFO:tensorflow:global_step/sec: 442.352
# INFO:tensorflow:loss = 0.28970796, step = 12801 (0.226 sec)
# INFO:tensorflow:global_step/sec: 324.769
# INFO:tensorflow:loss = 0.62594616, step = 12901 (0.308 sec)
# INFO:tensorflow:global_step/sec: 441.413
# INFO:tensorflow:loss = 0.2153531, step = 13001 (0.227 sec)
# INFO:tensorflow:global_step/sec: 444.575
# INFO:tensorflow:loss = 0.09567307, step = 13101 (0.224 sec)
# INFO:tensorflow:global_step/sec: 444.569
# INFO:tensorflow:loss = 0.44748116, step = 13201 (0.225 sec)
# INFO:tensorflow:global_step/sec: 373.659
# INFO:tensorflow:loss = 0.26754472, step = 13301 (0.268 sec)
# INFO:tensorflow:global_step/sec: 418.251
# INFO:tensorflow:loss = 0.54396236, step = 13401 (0.239 sec)
# INFO:tensorflow:global_step/sec: 373.526
# INFO:tensorflow:loss = 0.076443955, step = 13501 (0.268 sec)
# INFO:tensorflow:global_step/sec: 404.07
# INFO:tensorflow:loss = 0.06414779, step = 13601 (0.248 sec)
# INFO:tensorflow:global_step/sec: 428.541
# INFO:tensorflow:loss = 0.021150632, step = 13701 (0.233 sec)
# INFO:tensorflow:global_step/sec: 414.163
# INFO:tensorflow:loss = 0.16577165, step = 13801 (0.241 sec)
# INFO:tensorflow:global_step/sec: 408.655
# INFO:tensorflow:loss = 0.10047861, step = 13901 (0.245 sec)
# INFO:tensorflow:global_step/sec: 440.688
# INFO:tensorflow:loss = 0.4225209, step = 14001 (0.227 sec)
# INFO:tensorflow:global_step/sec: 387.686
# INFO:tensorflow:loss = 0.045048404, step = 14101 (0.258 sec)
# INFO:tensorflow:global_step/sec: 430.668
# INFO:tensorflow:loss = 0.15089414, step = 14201 (0.232 sec)
# INFO:tensorflow:global_step/sec: 366.471
# INFO:tensorflow:loss = 0.09425853, step = 14301 (0.273 sec)
# INFO:tensorflow:global_step/sec: 425.15
# INFO:tensorflow:loss = 0.023670204, step = 14401 (0.235 sec)
# INFO:tensorflow:global_step/sec: 371.181
# INFO:tensorflow:loss = 0.09779631, step = 14501 (0.270 sec)
# INFO:tensorflow:global_step/sec: 441.685
# INFO:tensorflow:loss = 0.046680506, step = 14601 (0.225 sec)
# INFO:tensorflow:global_step/sec: 391.083
# INFO:tensorflow:loss = 0.98052096, step = 14701 (0.257 sec)
# INFO:tensorflow:global_step/sec: 428.236
# INFO:tensorflow:loss = 0.011001002, step = 14801 (0.233 sec)
# INFO:tensorflow:global_step/sec: 408.499
# INFO:tensorflow:loss = 2.180697, step = 14901 (0.245 sec)
# INFO:tensorflow:global_step/sec: 421.555
# INFO:tensorflow:loss = 0.14606085, step = 15001 (0.237 sec)
# INFO:tensorflow:global_step/sec: 371.671
# INFO:tensorflow:loss = 0.05999682, step = 15101 (0.270 sec)
# INFO:tensorflow:global_step/sec: 439.489
# INFO:tensorflow:loss = 0.21234503, step = 15201 (0.226 sec)
# INFO:tensorflow:global_step/sec: 336.839
# INFO:tensorflow:loss = 0.08122159, step = 15301 (0.298 sec)
# INFO:tensorflow:global_step/sec: 393.159
# INFO:tensorflow:loss = 0.06378241, step = 15401 (0.254 sec)
# INFO:tensorflow:global_step/sec: 360.554
# INFO:tensorflow:loss = 0.17296717, step = 15501 (0.277 sec)
# INFO:tensorflow:global_step/sec: 448.857
# INFO:tensorflow:loss = 0.03495047, step = 15601 (0.223 sec)
# INFO:tensorflow:global_step/sec: 413.953
# INFO:tensorflow:loss = 0.047297023, step = 15701 (0.242 sec)
# INFO:tensorflow:global_step/sec: 381.407
# INFO:tensorflow:loss = 0.39892438, step = 15801 (0.262 sec)
# INFO:tensorflow:global_step/sec: 404.164
# INFO:tensorflow:loss = 0.07075515, step = 15901 (0.247 sec)
# INFO:tensorflow:global_step/sec: 423.916
# INFO:tensorflow:loss = 0.06971733, step = 16001 (0.236 sec)
# INFO:tensorflow:global_step/sec: 433.897
# INFO:tensorflow:loss = 0.04023002, step = 16101 (0.231 sec)
# INFO:tensorflow:global_step/sec: 381.267
# INFO:tensorflow:loss = 0.33806482, step = 16201 (0.262 sec)
# INFO:tensorflow:global_step/sec: 400.506
# INFO:tensorflow:loss = 0.26474726, step = 16301 (0.250 sec)
# INFO:tensorflow:global_step/sec: 426.285
# INFO:tensorflow:loss = 0.16447723, step = 16401 (0.235 sec)
# INFO:tensorflow:global_step/sec: 388.175
# INFO:tensorflow:loss = 0.061539676, step = 16501 (0.257 sec)
# INFO:tensorflow:global_step/sec: 399.201
# INFO:tensorflow:loss = 0.080459245, step = 16601 (0.251 sec)
# INFO:tensorflow:global_step/sec: 362.968
# INFO:tensorflow:loss = 0.019260572, step = 16701 (0.275 sec)
# INFO:tensorflow:global_step/sec: 369.079
# INFO:tensorflow:loss = 0.019322747, step = 16801 (0.271 sec)
# INFO:tensorflow:global_step/sec: 357.8
# INFO:tensorflow:loss = 0.16239491, step = 16901 (0.280 sec)
# INFO:tensorflow:global_step/sec: 372.139
# INFO:tensorflow:loss = 0.2632875, step = 17001 (0.268 sec)
# INFO:tensorflow:global_step/sec: 402.214
# INFO:tensorflow:loss = 0.22878592, step = 17101 (0.249 sec)
# INFO:tensorflow:global_step/sec: 373.727
# INFO:tensorflow:loss = 0.05614463, step = 17201 (0.267 sec)
# INFO:tensorflow:global_step/sec: 417.758
# INFO:tensorflow:loss = 0.1475663, step = 17301 (0.239 sec)
# INFO:tensorflow:global_step/sec: 405.946
# INFO:tensorflow:loss = 0.13241203, step = 17401 (0.246 sec)
# INFO:tensorflow:global_step/sec: 366.533
# INFO:tensorflow:loss = 0.024449036, step = 17501 (0.273 sec)
# INFO:tensorflow:global_step/sec: 363.839
# INFO:tensorflow:loss = 0.13378954, step = 17601 (0.275 sec)
# INFO:tensorflow:global_step/sec: 387.555
# INFO:tensorflow:loss = 0.027728582, step = 17701 (0.259 sec)
# INFO:tensorflow:global_step/sec: 349.822
# INFO:tensorflow:loss = 0.13785581, step = 17801 (0.285 sec)
# INFO:tensorflow:global_step/sec: 428.159
# INFO:tensorflow:loss = 0.062194284, step = 17901 (0.234 sec)
# INFO:tensorflow:global_step/sec: 353.929
# INFO:tensorflow:loss = 0.14608218, step = 18001 (0.282 sec)
# INFO:tensorflow:global_step/sec: 408.096
# INFO:tensorflow:loss = 0.15143582, step = 18101 (0.245 sec)
# INFO:tensorflow:global_step/sec: 368.688
# INFO:tensorflow:loss = 0.054975357, step = 18201 (0.271 sec)
# INFO:tensorflow:global_step/sec: 359.534
# INFO:tensorflow:loss = 0.050345484, step = 18301 (0.278 sec)
# INFO:tensorflow:global_step/sec: 431.988
# INFO:tensorflow:loss = 0.33779383, step = 18401 (0.231 sec)
# INFO:tensorflow:global_step/sec: 316.53
# INFO:tensorflow:loss = 0.11688398, step = 18501 (0.316 sec)
# INFO:tensorflow:global_step/sec: 392.599
# INFO:tensorflow:loss = 0.089030206, step = 18601 (0.255 sec)
# INFO:tensorflow:global_step/sec: 396.03
# INFO:tensorflow:loss = 0.036416784, step = 18701 (0.253 sec)
# INFO:tensorflow:global_step/sec: 424.833
# INFO:tensorflow:loss = 0.0013693313, step = 18801 (0.236 sec)
# INFO:tensorflow:global_step/sec: 410.497
# INFO:tensorflow:loss = 0.05860096, step = 18901 (0.243 sec)
# INFO:tensorflow:global_step/sec: 434.467
# INFO:tensorflow:loss = 0.12210952, step = 19001 (0.231 sec)
# INFO:tensorflow:global_step/sec: 325.202
# INFO:tensorflow:loss = 0.044740323, step = 19101 (0.307 sec)
# INFO:tensorflow:global_step/sec: 343.091
# INFO:tensorflow:loss = 0.10225195, step = 19201 (0.292 sec)
# INFO:tensorflow:global_step/sec: 386.183
# INFO:tensorflow:loss = 0.11130338, step = 19301 (0.259 sec)
# INFO:tensorflow:global_step/sec: 254.846
# INFO:tensorflow:loss = 0.104431264, step = 19401 (0.393 sec)
# INFO:tensorflow:global_step/sec: 244.213
# INFO:tensorflow:loss = 0.074486434, step = 19501 (0.409 sec)
# INFO:tensorflow:global_step/sec: 255.896
# INFO:tensorflow:loss = 0.12540546, step = 19601 (0.391 sec)
# INFO:tensorflow:global_step/sec: 267.977
# INFO:tensorflow:loss = 0.012362341, step = 19701 (0.372 sec)
# INFO:tensorflow:global_step/sec: 292.711
# INFO:tensorflow:loss = 0.118271075, step = 19801 (0.342 sec)
# INFO:tensorflow:global_step/sec: 303.79
# INFO:tensorflow:loss = 0.15123473, step = 19901 (0.328 sec)
# INFO:tensorflow:global_step/sec: 245.278
# INFO:tensorflow:loss = 0.25559965, step = 20001 (0.414 sec)
# INFO:tensorflow:global_step/sec: 224.307
# INFO:tensorflow:loss = 0.062294673, step = 20101 (0.440 sec)
# INFO:tensorflow:global_step/sec: 249.756
# INFO:tensorflow:loss = 0.037423596, step = 20201 (0.401 sec)
# INFO:tensorflow:global_step/sec: 269.636
# INFO:tensorflow:loss = 0.11375908, step = 20301 (0.371 sec)
# INFO:tensorflow:global_step/sec: 291.944
# INFO:tensorflow:loss = 0.09467779, step = 20401 (0.342 sec)
# INFO:tensorflow:global_step/sec: 284.695
# INFO:tensorflow:loss = 0.05671396, step = 20501 (0.351 sec)
# INFO:tensorflow:global_step/sec: 239.282
# INFO:tensorflow:loss = 0.04224714, step = 20601 (0.419 sec)
# INFO:tensorflow:global_step/sec: 289.316
# INFO:tensorflow:loss = 0.17967282, step = 20701 (0.345 sec)
# INFO:tensorflow:global_step/sec: 314.325
# INFO:tensorflow:loss = 0.1032368, step = 20801 (0.318 sec)
# INFO:tensorflow:global_step/sec: 279.585
# INFO:tensorflow:loss = 0.0074470835, step = 20901 (0.359 sec)
# INFO:tensorflow:global_step/sec: 277.116
# INFO:tensorflow:loss = 0.011596369, step = 21001 (0.360 sec)
# INFO:tensorflow:global_step/sec: 295.034
# INFO:tensorflow:loss = 0.03256048, step = 21101 (0.339 sec)
# INFO:tensorflow:global_step/sec: 275.528
# INFO:tensorflow:loss = 0.03865118, step = 21201 (0.363 sec)
# INFO:tensorflow:global_step/sec: 230.88
# INFO:tensorflow:loss = 0.04973768, step = 21301 (0.432 sec)
# INFO:tensorflow:global_step/sec: 280.173
# INFO:tensorflow:loss = 0.087912425, step = 21401 (0.359 sec)
# INFO:tensorflow:global_step/sec: 276.43
# INFO:tensorflow:loss = 0.08836064, step = 21501 (0.361 sec)
# INFO:tensorflow:global_step/sec: 274.511
# INFO:tensorflow:loss = 0.051765565, step = 21601 (0.364 sec)
# INFO:tensorflow:global_step/sec: 248.483
# INFO:tensorflow:loss = 0.015009104, step = 21701 (0.402 sec)
# INFO:tensorflow:global_step/sec: 242.053
# INFO:tensorflow:loss = 0.1377824, step = 21801 (0.414 sec)
# INFO:tensorflow:global_step/sec: 300.941
# INFO:tensorflow:loss = 0.038613603, step = 21901 (0.332 sec)
# INFO:tensorflow:global_step/sec: 251.778
# INFO:tensorflow:loss = 0.16367874, step = 22001 (0.398 sec)
# INFO:tensorflow:global_step/sec: 231.671
# INFO:tensorflow:loss = 0.013690178, step = 22101 (0.433 sec)
# INFO:tensorflow:global_step/sec: 247.05
# INFO:tensorflow:loss = 0.024327064, step = 22201 (0.404 sec)
# INFO:tensorflow:global_step/sec: 297.879
# INFO:tensorflow:loss = 0.047565654, step = 22301 (0.334 sec)
# INFO:tensorflow:global_step/sec: 212.797
# INFO:tensorflow:loss = 0.06992117, step = 22401 (0.470 sec)
# INFO:tensorflow:global_step/sec: 256.239
# INFO:tensorflow:loss = 0.0585014, step = 22501 (0.392 sec)
# INFO:tensorflow:global_step/sec: 245.03
# INFO:tensorflow:loss = 0.03857902, step = 22601 (0.407 sec)
# INFO:tensorflow:global_step/sec: 265.579
# INFO:tensorflow:loss = 0.19620663, step = 22701 (0.377 sec)
# INFO:tensorflow:global_step/sec: 231.392
# INFO:tensorflow:loss = 0.05579657, step = 22801 (0.432 sec)
# INFO:tensorflow:global_step/sec: 227.753
# INFO:tensorflow:loss = 0.24692805, step = 22901 (0.440 sec)
# INFO:tensorflow:global_step/sec: 293.618
# INFO:tensorflow:loss = 0.018398486, step = 23001 (0.346 sec)
# INFO:tensorflow:global_step/sec: 259.423
# INFO:tensorflow:loss = 0.079501994, step = 23101 (0.379 sec)
# INFO:tensorflow:global_step/sec: 266.386
# INFO:tensorflow:loss = 0.0033339015, step = 23201 (0.374 sec)
# INFO:tensorflow:global_step/sec: 323.539
# INFO:tensorflow:loss = 0.023564482, step = 23301 (0.309 sec)
# INFO:tensorflow:global_step/sec: 267.315
# INFO:tensorflow:loss = 0.015752483, step = 23401 (0.375 sec)
# INFO:tensorflow:global_step/sec: 251.723
# INFO:tensorflow:loss = 0.06783559, step = 23501 (0.396 sec)
# INFO:tensorflow:global_step/sec: 250.027
# INFO:tensorflow:loss = 0.030507218, step = 23601 (0.400 sec)
# INFO:tensorflow:global_step/sec: 275.93
# INFO:tensorflow:loss = 0.07451694, step = 23701 (0.362 sec)
# INFO:tensorflow:global_step/sec: 277.769
# INFO:tensorflow:loss = 0.07037873, step = 23801 (0.360 sec)
# INFO:tensorflow:global_step/sec: 355.575
# INFO:tensorflow:loss = 0.08907779, step = 23901 (0.281 sec)
# INFO:tensorflow:global_step/sec: 326.47
# INFO:tensorflow:loss = 0.10940114, step = 24001 (0.307 sec)
# INFO:tensorflow:global_step/sec: 247.925
# INFO:tensorflow:loss = 0.08034288, step = 24101 (0.404 sec)
# INFO:tensorflow:global_step/sec: 229.361
# INFO:tensorflow:loss = 0.04308919, step = 24201 (0.436 sec)
# INFO:tensorflow:global_step/sec: 277.007
# INFO:tensorflow:loss = 0.04762314, step = 24301 (0.362 sec)
# INFO:tensorflow:global_step/sec: 231.793
# INFO:tensorflow:loss = 0.26413232, step = 24401 (0.431 sec)
# INFO:tensorflow:global_step/sec: 238.521
# INFO:tensorflow:loss = 0.013322948, step = 24501 (0.418 sec)
# INFO:tensorflow:global_step/sec: 262.108
# INFO:tensorflow:loss = 0.016567428, step = 24601 (0.383 sec)
# INFO:tensorflow:global_step/sec: 212.111
# INFO:tensorflow:loss = 0.025308205, step = 24701 (0.471 sec)
# INFO:tensorflow:global_step/sec: 253.986
# INFO:tensorflow:loss = 0.045242436, step = 24801 (0.395 sec)
# INFO:tensorflow:global_step/sec: 313.212
# INFO:tensorflow:loss = 0.076107614, step = 24901 (0.318 sec)
# INFO:tensorflow:global_step/sec: 370.739
# INFO:tensorflow:loss = 0.010281103, step = 25001 (0.269 sec)
# INFO:tensorflow:global_step/sec: 319.124
# INFO:tensorflow:loss = 0.021707153, step = 25101 (0.313 sec)
# INFO:tensorflow:global_step/sec: 304.971
# INFO:tensorflow:loss = 0.21908885, step = 25201 (0.328 sec)
# INFO:tensorflow:global_step/sec: 297.327
# INFO:tensorflow:loss = 0.0007965865, step = 25301 (0.337 sec)
# INFO:tensorflow:global_step/sec: 286.944
# INFO:tensorflow:loss = 0.09046829, step = 25401 (0.348 sec)
# INFO:tensorflow:global_step/sec: 308.631
# INFO:tensorflow:loss = 0.15088743, step = 25501 (0.323 sec)
# INFO:tensorflow:global_step/sec: 366.794
# INFO:tensorflow:loss = 0.03137107, step = 25601 (0.272 sec)
# INFO:tensorflow:global_step/sec: 255.157
# INFO:tensorflow:loss = 0.03213891, step = 25701 (0.393 sec)
# INFO:tensorflow:global_step/sec: 322.387
# INFO:tensorflow:loss = 0.029787116, step = 25801 (0.310 sec)
# INFO:tensorflow:global_step/sec: 258.321
# INFO:tensorflow:loss = 0.02848081, step = 25901 (0.387 sec)
# INFO:tensorflow:global_step/sec: 236.395
# INFO:tensorflow:loss = 0.11476776, step = 26001 (0.424 sec)
# INFO:tensorflow:global_step/sec: 245.094
# INFO:tensorflow:loss = 0.01694671, step = 26101 (0.408 sec)
# INFO:tensorflow:global_step/sec: 298.135
# INFO:tensorflow:loss = 0.019549277, step = 26201 (0.334 sec)
# INFO:tensorflow:global_step/sec: 277.306
# INFO:tensorflow:loss = 0.02650863, step = 26301 (0.360 sec)
# INFO:tensorflow:global_step/sec: 313.685
# INFO:tensorflow:loss = 0.05919935, step = 26401 (0.320 sec)
# INFO:tensorflow:global_step/sec: 365.235
# INFO:tensorflow:loss = 0.011741316, step = 26501 (0.274 sec)
# INFO:tensorflow:global_step/sec: 355.11
# INFO:tensorflow:loss = 0.060278773, step = 26601 (0.283 sec)
# INFO:tensorflow:global_step/sec: 352.466
# INFO:tensorflow:loss = 0.063518986, step = 26701 (0.282 sec)
# INFO:tensorflow:global_step/sec: 339.748
# INFO:tensorflow:loss = 0.008401821, step = 26801 (0.294 sec)
# INFO:tensorflow:global_step/sec: 371.519
# INFO:tensorflow:loss = 0.02188479, step = 26901 (0.269 sec)
# INFO:tensorflow:global_step/sec: 303.637
# INFO:tensorflow:loss = 0.16434199, step = 27001 (0.329 sec)
# INFO:tensorflow:global_step/sec: 307.652
# INFO:tensorflow:loss = 0.04392776, step = 27101 (0.327 sec)
# INFO:tensorflow:global_step/sec: 298.21
# INFO:tensorflow:loss = 0.027271159, step = 27201 (0.335 sec)
# INFO:tensorflow:global_step/sec: 302.764
# INFO:tensorflow:loss = 0.024973836, step = 27301 (0.331 sec)
# INFO:tensorflow:global_step/sec: 339.271
# INFO:tensorflow:loss = 0.004481301, step = 27401 (0.294 sec)
# INFO:tensorflow:global_step/sec: 347.458
# INFO:tensorflow:loss = 0.04694488, step = 27501 (0.288 sec)
# INFO:tensorflow:global_step/sec: 319.979
# INFO:tensorflow:loss = 0.016582666, step = 27601 (0.312 sec)
# INFO:tensorflow:global_step/sec: 338.594
# INFO:tensorflow:loss = 0.037791166, step = 27701 (0.295 sec)
# INFO:tensorflow:global_step/sec: 350.214
# INFO:tensorflow:loss = 0.0055288645, step = 27801 (0.285 sec)
# INFO:tensorflow:global_step/sec: 371.842
# INFO:tensorflow:loss = 0.0020348902, step = 27901 (0.269 sec)
# INFO:tensorflow:global_step/sec: 350.277
# INFO:tensorflow:loss = 0.022324078, step = 28001 (0.286 sec)
# INFO:tensorflow:global_step/sec: 344.849
# INFO:tensorflow:loss = 0.094512224, step = 28101 (0.290 sec)
# INFO:tensorflow:global_step/sec: 349.41
# INFO:tensorflow:loss = 0.019898219, step = 28201 (0.287 sec)
# INFO:tensorflow:global_step/sec: 238.618
# INFO:tensorflow:loss = 0.026920691, step = 28301 (0.420 sec)
# INFO:tensorflow:global_step/sec: 295.802
# INFO:tensorflow:loss = 0.00717243, step = 28401 (0.337 sec)
# INFO:tensorflow:global_step/sec: 307.775
# INFO:tensorflow:loss = 0.049685545, step = 28501 (0.326 sec)
# INFO:tensorflow:global_step/sec: 309.029
# INFO:tensorflow:loss = 0.012596254, step = 28601 (0.322 sec)
# INFO:tensorflow:global_step/sec: 324.454
# INFO:tensorflow:loss = 0.008984502, step = 28701 (0.308 sec)
# INFO:tensorflow:global_step/sec: 331.445
# INFO:tensorflow:loss = 0.023243021, step = 28801 (0.305 sec)
# INFO:tensorflow:global_step/sec: 285.556
# INFO:tensorflow:loss = 0.015919961, step = 28901 (0.348 sec)
# INFO:tensorflow:global_step/sec: 342.134
# INFO:tensorflow:loss = 0.03717455, step = 29001 (0.292 sec)
# INFO:tensorflow:global_step/sec: 324.579
# INFO:tensorflow:loss = 0.013512647, step = 29101 (0.308 sec)
# INFO:tensorflow:global_step/sec: 294.572
# INFO:tensorflow:loss = 0.062003955, step = 29201 (0.341 sec)
# INFO:tensorflow:global_step/sec: 328.059
# INFO:tensorflow:loss = 0.048301205, step = 29301 (0.303 sec)
# INFO:tensorflow:global_step/sec: 311.302
# INFO:tensorflow:loss = 0.021106824, step = 29401 (0.321 sec)
# INFO:tensorflow:global_step/sec: 216.615
# INFO:tensorflow:loss = 0.007093771, step = 29501 (0.463 sec)
# INFO:tensorflow:global_step/sec: 321.69
# INFO:tensorflow:loss = 0.00826789, step = 29601 (0.310 sec)
# INFO:tensorflow:global_step/sec: 324.825
# INFO:tensorflow:loss = 0.0356147, step = 29701 (0.308 sec)
# INFO:tensorflow:global_step/sec: 341.061
# INFO:tensorflow:loss = 0.023866562, step = 29801 (0.293 sec)
# INFO:tensorflow:global_step/sec: 380.555
# INFO:tensorflow:loss = 0.015376767, step = 29901 (0.262 sec)
# INFO:tensorflow:global_step/sec: 325.707
# INFO:tensorflow:loss = 0.009959009, step = 30001 (0.308 sec)
# INFO:tensorflow:global_step/sec: 334.842
# INFO:tensorflow:loss = 0.011732012, step = 30101 (0.298 sec)
# INFO:tensorflow:global_step/sec: 317.885
# INFO:tensorflow:loss = 0.03602004, step = 30201 (0.315 sec)
# INFO:tensorflow:global_step/sec: 330.264
# INFO:tensorflow:loss = 0.041253977, step = 30301 (0.303 sec)
# INFO:tensorflow:global_step/sec: 296.521
# INFO:tensorflow:loss = 0.07109792, step = 30401 (0.337 sec)
# INFO:tensorflow:global_step/sec: 275.923
# INFO:tensorflow:loss = 0.02161691, step = 30501 (0.362 sec)
# INFO:tensorflow:global_step/sec: 316.123
# INFO:tensorflow:loss = 0.07072684, step = 30601 (0.319 sec)
# INFO:tensorflow:global_step/sec: 264.901
# INFO:tensorflow:loss = 0.018758105, step = 30701 (0.374 sec)
# INFO:tensorflow:global_step/sec: 325.298
# INFO:tensorflow:loss = 0.06177854, step = 30801 (0.308 sec)
# INFO:tensorflow:global_step/sec: 270.544
# INFO:tensorflow:loss = 0.013248661, step = 30901 (0.369 sec)
# INFO:tensorflow:global_step/sec: 249.338
# INFO:tensorflow:loss = 0.015297248, step = 31001 (0.402 sec)
# INFO:tensorflow:global_step/sec: 317.06
# INFO:tensorflow:loss = 0.02834731, step = 31101 (0.316 sec)
# INFO:tensorflow:global_step/sec: 259.573
# INFO:tensorflow:loss = 0.02932903, step = 31201 (0.384 sec)
# INFO:tensorflow:global_step/sec: 261.488
# INFO:tensorflow:loss = 0.0013746046, step = 31301 (0.383 sec)
# INFO:tensorflow:global_step/sec: 301.268
# INFO:tensorflow:loss = 0.015906993, step = 31401 (0.332 sec)
# INFO:tensorflow:global_step/sec: 246.885
# INFO:tensorflow:loss = 0.019625781, step = 31501 (0.405 sec)
# INFO:tensorflow:global_step/sec: 327.409
# INFO:tensorflow:loss = 0.029996037, step = 31601 (0.306 sec)
# INFO:tensorflow:global_step/sec: 252.114
# INFO:tensorflow:loss = 0.028579403, step = 31701 (0.396 sec)
# INFO:tensorflow:global_step/sec: 229.099
# INFO:tensorflow:loss = 0.025008693, step = 31801 (0.437 sec)
# INFO:tensorflow:global_step/sec: 275.588
# INFO:tensorflow:loss = 0.02886459, step = 31901 (0.362 sec)
# INFO:tensorflow:global_step/sec: 350.176
# INFO:tensorflow:loss = 0.0014836293, step = 32001 (0.285 sec)
# INFO:tensorflow:global_step/sec: 364.389
# INFO:tensorflow:loss = 0.052107155, step = 32101 (0.275 sec)
# INFO:tensorflow:global_step/sec: 354.866
# INFO:tensorflow:loss = 0.003581084, step = 32201 (0.283 sec)
# INFO:tensorflow:global_step/sec: 305.105
# INFO:tensorflow:loss = 0.017112698, step = 32301 (0.326 sec)
# INFO:tensorflow:global_step/sec: 357.082
# INFO:tensorflow:loss = 0.036346912, step = 32401 (0.281 sec)
# INFO:tensorflow:global_step/sec: 360.193
# INFO:tensorflow:loss = 0.061372377, step = 32501 (0.278 sec)
# INFO:tensorflow:global_step/sec: 374.121
# INFO:tensorflow:loss = 0.031032603, step = 32601 (0.267 sec)
# INFO:tensorflow:global_step/sec: 339.803
# INFO:tensorflow:loss = 0.027760983, step = 32701 (0.295 sec)
# INFO:tensorflow:global_step/sec: 307.401
# INFO:tensorflow:loss = 0.03442225, step = 32801 (0.325 sec)
# INFO:tensorflow:global_step/sec: 360.644
# INFO:tensorflow:loss = 0.029641705, step = 32901 (0.277 sec)
# INFO:tensorflow:global_step/sec: 370.319
# INFO:tensorflow:loss = 0.009405561, step = 33001 (0.271 sec)
# INFO:tensorflow:global_step/sec: 309.041
# INFO:tensorflow:loss = 0.011176851, step = 33101 (0.323 sec)
# INFO:tensorflow:global_step/sec: 353.457
# INFO:tensorflow:loss = 0.0132819675, step = 33201 (0.283 sec)
# INFO:tensorflow:global_step/sec: 306.615
# INFO:tensorflow:loss = 0.014725275, step = 33301 (0.327 sec)
# INFO:tensorflow:global_step/sec: 297.043
# INFO:tensorflow:loss = 0.011554405, step = 33401 (0.336 sec)
# INFO:tensorflow:global_step/sec: 340.978
# INFO:tensorflow:loss = 0.03182691, step = 33501 (0.294 sec)
# INFO:tensorflow:global_step/sec: 375.105
# INFO:tensorflow:loss = 0.011960111, step = 33601 (0.266 sec)
# INFO:tensorflow:global_step/sec: 317.601
# INFO:tensorflow:loss = 0.025320062, step = 33701 (0.316 sec)
# INFO:tensorflow:global_step/sec: 351.86
# INFO:tensorflow:loss = 0.036738653, step = 33801 (0.284 sec)
# INFO:tensorflow:global_step/sec: 321.563
# INFO:tensorflow:loss = 0.02126673, step = 33901 (0.311 sec)
# INFO:tensorflow:global_step/sec: 331.136
# INFO:tensorflow:loss = 0.03713545, step = 34001 (0.301 sec)
# INFO:tensorflow:global_step/sec: 340.828
# INFO:tensorflow:loss = 0.028044296, step = 34101 (0.293 sec)
# INFO:tensorflow:global_step/sec: 308.895
# INFO:tensorflow:loss = 0.045797303, step = 34201 (0.325 sec)
# INFO:tensorflow:global_step/sec: 309.087
# INFO:tensorflow:loss = 0.0857153, step = 34301 (0.323 sec)
# INFO:tensorflow:global_step/sec: 325.626
# INFO:tensorflow:loss = 0.0036392196, step = 34401 (0.308 sec)
# INFO:tensorflow:global_step/sec: 327.674
# INFO:tensorflow:loss = 0.008222339, step = 34501 (0.305 sec)
# INFO:tensorflow:global_step/sec: 323.047
# INFO:tensorflow:loss = 0.017318435, step = 34601 (0.309 sec)
# INFO:tensorflow:global_step/sec: 307.791
# INFO:tensorflow:loss = 0.076806225, step = 34701 (0.325 sec)
# INFO:tensorflow:global_step/sec: 321.045
# INFO:tensorflow:loss = 0.042153176, step = 34801 (0.310 sec)
# INFO:tensorflow:global_step/sec: 327.009
# INFO:tensorflow:loss = 0.00702516, step = 34901 (0.308 sec)
# INFO:tensorflow:global_step/sec: 229.883
# INFO:tensorflow:loss = 0.022849435, step = 35001 (0.435 sec)
# INFO:tensorflow:global_step/sec: 264.873
# INFO:tensorflow:loss = 0.038363334, step = 35101 (0.376 sec)
# INFO:tensorflow:global_step/sec: 232.168
# INFO:tensorflow:loss = 0.0035204121, step = 35201 (0.432 sec)
# INFO:tensorflow:global_step/sec: 282.473
# INFO:tensorflow:loss = 0.005348309, step = 35301 (0.353 sec)
# INFO:tensorflow:global_step/sec: 254.765
# INFO:tensorflow:loss = 0.036171086, step = 35401 (0.393 sec)
# INFO:tensorflow:global_step/sec: 244.599
# INFO:tensorflow:loss = 0.014206968, step = 35501 (0.408 sec)
# INFO:tensorflow:global_step/sec: 230.132
# INFO:tensorflow:loss = 0.0024974018, step = 35601 (0.434 sec)
# INFO:tensorflow:global_step/sec: 298.746
# INFO:tensorflow:loss = 0.008395843, step = 35701 (0.335 sec)
# INFO:tensorflow:global_step/sec: 220.804
# INFO:tensorflow:loss = 0.022920296, step = 35801 (0.454 sec)
# INFO:tensorflow:global_step/sec: 242.71
# INFO:tensorflow:loss = 0.0038574445, step = 35901 (0.412 sec)
# INFO:tensorflow:global_step/sec: 268.808
# INFO:tensorflow:loss = 0.025455317, step = 36001 (0.372 sec)
# INFO:tensorflow:global_step/sec: 259.672
# INFO:tensorflow:loss = 0.057635218, step = 36101 (0.386 sec)
# INFO:tensorflow:global_step/sec: 244.265
# INFO:tensorflow:loss = 0.011450262, step = 36201 (0.412 sec)
# INFO:tensorflow:global_step/sec: 277.975
# INFO:tensorflow:loss = 0.033232942, step = 36301 (0.357 sec)
# INFO:tensorflow:global_step/sec: 356.632
# INFO:tensorflow:loss = 0.030966882, step = 36401 (0.280 sec)
# INFO:tensorflow:global_step/sec: 356.642
# INFO:tensorflow:loss = 0.009139167, step = 36501 (0.279 sec)
# INFO:tensorflow:global_step/sec: 348.292
# INFO:tensorflow:loss = 0.038355116, step = 36601 (0.288 sec)
# INFO:tensorflow:global_step/sec: 293.072
# INFO:tensorflow:loss = 0.013285128, step = 36701 (0.342 sec)
# INFO:tensorflow:global_step/sec: 280.656
# INFO:tensorflow:loss = 0.0069980943, step = 36801 (0.356 sec)
# INFO:tensorflow:global_step/sec: 314.15
# INFO:tensorflow:loss = 0.0062873377, step = 36901 (0.318 sec)
# INFO:tensorflow:global_step/sec: 329.397
# INFO:tensorflow:loss = 0.02508034, step = 37001 (0.303 sec)
# INFO:tensorflow:global_step/sec: 319.243
# INFO:tensorflow:loss = 0.012437453, step = 37101 (0.313 sec)
# INFO:tensorflow:global_step/sec: 353.96
# INFO:tensorflow:loss = 0.045988448, step = 37201 (0.283 sec)
# INFO:tensorflow:global_step/sec: 344.485
# INFO:tensorflow:loss = 0.045006618, step = 37301 (0.289 sec)
# INFO:tensorflow:global_step/sec: 312.576
# INFO:tensorflow:loss = 0.03438132, step = 37401 (0.320 sec)
# INFO:tensorflow:global_step/sec: 341.092
# INFO:tensorflow:loss = 0.012924816, step = 37501 (0.294 sec)
# INFO:tensorflow:global_step/sec: 319.853
# INFO:tensorflow:loss = 0.00085553085, step = 37601 (0.312 sec)
# INFO:tensorflow:global_step/sec: 324.262
# INFO:tensorflow:loss = 0.0131506, step = 37701 (0.309 sec)
# INFO:tensorflow:global_step/sec: 309.294
# INFO:tensorflow:loss = 0.0030604054, step = 37801 (0.323 sec)
# INFO:tensorflow:global_step/sec: 308.624
# INFO:tensorflow:loss = 0.011579474, step = 37901 (0.325 sec)
# INFO:tensorflow:global_step/sec: 276.242
# INFO:tensorflow:loss = 0.011995622, step = 38001 (0.362 sec)
# INFO:tensorflow:global_step/sec: 346.754
# INFO:tensorflow:loss = 0.0023810267, step = 38101 (0.287 sec)
# INFO:tensorflow:global_step/sec: 333.958
# INFO:tensorflow:loss = 0.0010013838, step = 38201 (0.299 sec)
# INFO:tensorflow:global_step/sec: 294.362
# INFO:tensorflow:loss = 0.038221553, step = 38301 (0.340 sec)
# INFO:tensorflow:global_step/sec: 289.071
# INFO:tensorflow:loss = 0.018653762, step = 38401 (0.346 sec)
# INFO:tensorflow:global_step/sec: 321.818
# INFO:tensorflow:loss = 0.021150798, step = 38501 (0.311 sec)
# INFO:tensorflow:global_step/sec: 347.266
# INFO:tensorflow:loss = 0.007319644, step = 38601 (0.288 sec)
# INFO:tensorflow:global_step/sec: 338.486
# INFO:tensorflow:loss = 0.0056379535, step = 38701 (0.295 sec)
# INFO:tensorflow:global_step/sec: 339.979
# INFO:tensorflow:loss = 0.027045483, step = 38801 (0.294 sec)
# INFO:tensorflow:global_step/sec: 310.745
# INFO:tensorflow:loss = 0.058667153, step = 38901 (0.323 sec)
# INFO:tensorflow:global_step/sec: 347.528
# INFO:tensorflow:loss = 0.007655094, step = 39001 (0.287 sec)
# INFO:tensorflow:global_step/sec: 311.794
# INFO:tensorflow:loss = 0.0069197468, step = 39101 (0.321 sec)
# INFO:tensorflow:global_step/sec: 333.852
# INFO:tensorflow:loss = 0.004726241, step = 39201 (0.300 sec)
# INFO:tensorflow:global_step/sec: 335.788
# INFO:tensorflow:loss = 0.0025354987, step = 39301 (0.297 sec)
# INFO:tensorflow:global_step/sec: 322.247
# INFO:tensorflow:loss = 0.002327541, step = 39401 (0.311 sec)
# INFO:tensorflow:global_step/sec: 280.537
# INFO:tensorflow:loss = 0.007931118, step = 39501 (0.357 sec)
# INFO:tensorflow:global_step/sec: 315.088
# INFO:tensorflow:loss = 0.023694875, step = 39601 (0.317 sec)
# INFO:tensorflow:global_step/sec: 301.735
# INFO:tensorflow:loss = 0.050646648, step = 39701 (0.332 sec)
# INFO:tensorflow:global_step/sec: 354.532
# INFO:tensorflow:loss = 0.03269878, step = 39801 (0.281 sec)
# INFO:tensorflow:global_step/sec: 320.117
# INFO:tensorflow:loss = 0.018540412, step = 39901 (0.313 sec)
# INFO:tensorflow:global_step/sec: 332.175
# INFO:tensorflow:loss = 0.01910215, step = 40001 (0.301 sec)
# INFO:tensorflow:global_step/sec: 318.463
# INFO:tensorflow:loss = 0.016556779, step = 40101 (0.313 sec)
# INFO:tensorflow:global_step/sec: 306.709
# INFO:tensorflow:loss = 0.015162464, step = 40201 (0.326 sec)
# INFO:tensorflow:global_step/sec: 373.721
# INFO:tensorflow:loss = 0.02831269, step = 40301 (0.267 sec)
# INFO:tensorflow:global_step/sec: 400.226
# INFO:tensorflow:loss = 0.0070294645, step = 40401 (0.250 sec)
# INFO:tensorflow:global_step/sec: 379.397
# INFO:tensorflow:loss = 0.005586383, step = 40501 (0.263 sec)
# INFO:tensorflow:global_step/sec: 416.55
# INFO:tensorflow:loss = 0.011883911, step = 40601 (0.240 sec)
# INFO:tensorflow:global_step/sec: 409.686
# INFO:tensorflow:loss = 0.0008896367, step = 40701 (0.244 sec)
# INFO:tensorflow:global_step/sec: 403.837
# INFO:tensorflow:loss = 0.006717586, step = 40801 (0.248 sec)
# INFO:tensorflow:global_step/sec: 402.207
# INFO:tensorflow:loss = 0.0032638106, step = 40901 (0.248 sec)
# INFO:tensorflow:global_step/sec: 406.727
# INFO:tensorflow:loss = 0.0030364245, step = 41001 (0.246 sec)
# INFO:tensorflow:global_step/sec: 422.788
# INFO:tensorflow:loss = 0.05116275, step = 41101 (0.237 sec)
# INFO:tensorflow:global_step/sec: 419.576
# INFO:tensorflow:loss = 0.030365031, step = 41201 (0.238 sec)
# INFO:tensorflow:global_step/sec: 409.851
# INFO:tensorflow:loss = 0.06395203, step = 41301 (0.244 sec)
# INFO:tensorflow:global_step/sec: 385.429
# INFO:tensorflow:loss = 0.0090138335, step = 41401 (0.259 sec)
# INFO:tensorflow:global_step/sec: 436.741
# INFO:tensorflow:loss = 0.016581997, step = 41501 (0.229 sec)
# INFO:tensorflow:global_step/sec: 436.355
# INFO:tensorflow:loss = 0.026223974, step = 41601 (0.229 sec)
# INFO:tensorflow:global_step/sec: 419.831
# INFO:tensorflow:loss = 0.020732116, step = 41701 (0.239 sec)
# INFO:tensorflow:global_step/sec: 439.531
# INFO:tensorflow:loss = 0.039073654, step = 41801 (0.227 sec)
# INFO:tensorflow:global_step/sec: 374.929
# INFO:tensorflow:loss = 0.007039074, step = 41901 (0.267 sec)
# INFO:tensorflow:global_step/sec: 412.395
# INFO:tensorflow:loss = 0.011455973, step = 42001 (0.243 sec)
# INFO:tensorflow:global_step/sec: 394.157
# INFO:tensorflow:loss = 0.040593185, step = 42101 (0.254 sec)
# INFO:tensorflow:global_step/sec: 423.86
# INFO:tensorflow:loss = 0.060502697, step = 42201 (0.235 sec)
# INFO:tensorflow:global_step/sec: 426.862
# INFO:tensorflow:loss = 0.0027678185, step = 42301 (0.234 sec)
# INFO:tensorflow:global_step/sec: 430.67
# INFO:tensorflow:loss = 0.039170817, step = 42401 (0.232 sec)
# INFO:tensorflow:global_step/sec: 418.906
# INFO:tensorflow:loss = 0.033930533, step = 42501 (0.239 sec)
# INFO:tensorflow:global_step/sec: 385.705
# INFO:tensorflow:loss = 0.025043307, step = 42601 (0.260 sec)
# INFO:tensorflow:global_step/sec: 367.139
# INFO:tensorflow:loss = 0.03268467, step = 42701 (0.272 sec)
# INFO:tensorflow:global_step/sec: 411.454
# INFO:tensorflow:loss = 0.024145346, step = 42801 (0.242 sec)
# INFO:tensorflow:global_step/sec: 419.031
# INFO:tensorflow:loss = 0.023569066, step = 42901 (0.239 sec)
# INFO:tensorflow:global_step/sec: 417.479
# INFO:tensorflow:loss = 0.042783357, step = 43001 (0.240 sec)
# INFO:tensorflow:global_step/sec: 410.041
# INFO:tensorflow:loss = 0.002326008, step = 43101 (0.244 sec)
# INFO:tensorflow:global_step/sec: 404.832
# INFO:tensorflow:loss = 0.013470899, step = 43201 (0.247 sec)
# INFO:tensorflow:global_step/sec: 428.181
# INFO:tensorflow:loss = 0.0183591, step = 43301 (0.233 sec)
# INFO:tensorflow:global_step/sec: 439.186
# INFO:tensorflow:loss = 0.0064638117, step = 43401 (0.228 sec)
# INFO:tensorflow:global_step/sec: 444.008
# INFO:tensorflow:loss = 0.011571104, step = 43501 (0.226 sec)
# INFO:tensorflow:global_step/sec: 412.815
# INFO:tensorflow:loss = 0.015941268, step = 43601 (0.242 sec)
# INFO:tensorflow:global_step/sec: 421.93
# INFO:tensorflow:loss = 0.0037431242, step = 43701 (0.237 sec)
# INFO:tensorflow:global_step/sec: 430.187
# INFO:tensorflow:loss = 0.07686126, step = 43801 (0.232 sec)
# INFO:tensorflow:global_step/sec: 381.813
# INFO:tensorflow:loss = 0.015830394, step = 43901 (0.263 sec)
# INFO:tensorflow:Saving checkpoints for 44000 into /var/folders/1p/9j4_29dj62jf1c6tc1qqmk140000gn/T/tmpbvepjwbn/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.0016562346.

# %% [markdown]
# ### evaluate metrics

# %%
test_input_fn = tf.estimator.inputs.numpy_input_fn(
    x={"X": X_test}, y=y_test, shuffle=False)
eval_results = dnn_clf.evaluate(input_fn=test_input_fn)
# Out:
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-03-23T04:10:52Z
# INFO:tensorflow:Graph was finalized.
# WARNING:tensorflow:From /anaconda3/lib/python3.6/site-packages/tensorflow/python/training/saver.py:1266: checkpoint_exists (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to check for files with this prefix.
# INFO:tensorflow:Restoring parameters from /var/folders/1p/9j4_29dj62jf1c6tc1qqmk140000gn/T/tmpbvepjwbn/model.ckpt-44000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-03-23-04:10:52
# INFO:tensorflow:Saving dict for global step 44000: accuracy = 0.9779, average_loss = 0.10576631, global_step = 44000, loss = 13.388141
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 44000: /var/folders/1p/9j4_29dj62jf1c6tc1qqmk140000gn/T/tmpbvepjwbn/model.ckpt-44000

# %%
eval_results
# Out:
# {'accuracy': 0.9779,
#  'average_loss': 0.10576631,
#  'loss': 13.388141,
#  'global_step': 44000}

# %%
y_pred_iter = dnn_clf.predict(input_fn=test_input_fn)
y_pred = list(y_pred_iter)
y_pred[0]
# Out:
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /var/folders/1p/9j4_29dj62jf1c6tc1qqmk140000gn/T/tmpbvepjwbn/model.ckpt-44000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# {'logits': array([-11.029446 ,   2.6809397,  -5.0362144,   2.0475237, -10.583523 ,
#         -11.072868 , -24.23713  ,  19.431154 ,  -5.1649723,   1.053862 ],
#        dtype=float32),
#  'probabilities': array([5.9037715e-14, 5.3146497e-08, 2.3656833e-11, 2.8208831e-08,
#         9.2212838e-14, 5.6529000e-14, 1.0841922e-19, 1.0000000e+00,
#         2.0798785e-11, 1.0443431e-08], dtype=float32),
#  'class_ids': array([7]),
#  'classes': array([b'7'], dtype=object)}

# %% [markdown]
# ### dnn via lower level tf api:
# -  low level api is used for more control over the architecture of the network
# -  Part 1 => construction phase (BUILD TF GRAPH):
#     1.  create placeholders for inputs / targets
#     2.  create func to build nueron layer
#     3.  use nueron layer func to create DNN
#     4.  define cost function
#     5.  create optimizer
#     6.  define perf measure
# -  Part 2 => execution phase (RUN GRAPH TO TRAIN MODEL):
#     1.  define number of epochs / mini-batch size
#     2.  train model
# -  **V1 => via custom udf**
# -  **V2 => via built-in tf func**

# %% [markdown]
# ### V1

# %%
# 1 => create placeholders for inputs / targets
n_inputs = 28*28  # MNIST features; 28*28 = 784 neurons required
n_hidden1 = 300 # number of neurons
n_hidden2 = 100 # number of neurons
n_outputs = 10 # number of neurons

# %%
# 1 => create placeholders for inputs / targets
tf.reset_default_graph()

# shape = None because unsure how many training instances each batch will contain

# X => 2D tensor (matrix) w/ instances as 1st dim and features as 2nd dim
X = tf.placeholder(tf.float32, shape=(None, n_inputs), name="X") # input layer during execution phase
# y => 1D tensor w/ 1 entry per instance
y = tf.placeholder(tf.int32, shape=(None), name="y")

# %%
# 2 => create func to build nueron layer
def neuron_layer(X, n_neurons, name, activation=None):
    """
    X => inputs
    n_neurons => # of neruons
    name => name of layer
    activation = activation func
    """
    with tf.name_scope(name):
        n_inputs = int(X.get_shape()[1])
        stddev = 2 / np.sqrt(n_inputs)
        init = tf.truncated_normal((n_inputs, n_neurons), stddev=stddev) # stddev makes DNN more efficient
        W = tf.Variable(init, name="kernel")
        b = tf.Variable(tf.zeros([n_neurons]), name="bias")
        Z = tf.matmul(X, W) + b
        if activation is not None:
            return activation(Z)
        else:
            return Z

# %%
# 3 => use nueron layer func to create DNN
with tf.name_scope("dnn"):
    hidden1 = neuron_layer(X, n_hidden1, name="hidden1", # X as input
                           activation=tf.nn.relu)
    hidden2 = neuron_layer(hidden1, n_hidden2, name="hidden2", # hidden1 output as input
                           activation=tf.nn.relu)
    logits = neuron_layer(hidden2, n_outputs, name="outputs") # hidden2 output as input; ready for input to activation func

# %%
# 4 => define cost function
with tf.name_scope("loss"): # cost func for training
    xentropy = tf.nn.sparse_softmax_cross_entropy_with_logits(labels=y,
                                                              logits=logits)
    loss = tf.reduce_mean(xentropy, name="loss")

# %%
# 5 => create optimizer
learning_rate = 0.01

with tf.name_scope("train"):
    optimizer = tf.train.GradientDescentOptimizer(learning_rate) # GDO for tweaking model parameters to min cost func
    training_op = optimizer.minimize(loss)

# %%
# 6 => define perf measure
with tf.name_scope("eval"): # model eval
    correct = tf.nn.in_top_k(logits, y, 1)
    accuracy = tf.reduce_mean(tf.cast(correct, tf.float32))

# %%
init = tf.global_variables_initializer() # initialize variables
saver = tf.train.Saver() # save trained model params to disk

# %%
# 1 => define number of epochs / mini-batch size
n_epochs = 40
batch_size = 50

# %%
def shuffle_batch(X, y, batch_size):
    rnd_idx = np.random.permutation(len(X))
    n_batches = len(X) // batch_size
    for batch_idx in np.array_split(rnd_idx, n_batches):
        X_batch, y_batch = X[batch_idx], y[batch_idx]
        yield X_batch, y_batch

# %%
# 2 => train model
with tf.Session() as sess: # open tf session
    init.run() # run init node to initialize all vars
    for epoch in range(n_epochs):
        for X_batch, y_batch in shuffle_batch(X_train, y_train, batch_size):
            sess.run(training_op, feed_dict={X: X_batch, y: y_batch})
        acc_batch = accuracy.eval(feed_dict={X: X_batch, y: y_batch})
        acc_val = accuracy.eval(feed_dict={X: X_valid, y: y_valid})
        print(epoch, "Batch accuracy:", acc_batch, "Val accuracy:", acc_val)

    save_path = saver.save(sess, "./my_model_final_v1.ckpt")
# Out:
# 0 Batch accuracy: 0.9 Val accuracy: 0.9168
# 1 Batch accuracy: 0.92 Val accuracy: 0.9332
# 2 Batch accuracy: 0.96 Val accuracy: 0.9414
# 3 Batch accuracy: 0.94 Val accuracy: 0.949
# 4 Batch accuracy: 0.98 Val accuracy: 0.9552
# 5 Batch accuracy: 0.96 Val accuracy: 0.9582
# 6 Batch accuracy: 0.98 Val accuracy: 0.9622
# 7 Batch accuracy: 0.96 Val accuracy: 0.9614
# 8 Batch accuracy: 0.96 Val accuracy: 0.9636
# 9 Batch accuracy: 1.0 Val accuracy: 0.9656
# 10 Batch accuracy: 1.0 Val accuracy: 0.967
# 11 Batch accuracy: 0.96 Val accuracy: 0.9676
# 12 Batch accuracy: 1.0 Val accuracy: 0.9684
# 13 Batch accuracy: 0.98 Val accuracy: 0.9698
# 14 Batch accuracy: 1.0 Val accuracy: 0.9694
# 15 Batch accuracy: 1.0 Val accuracy: 0.9716
# 16 Batch accuracy: 1.0 Val accuracy: 0.973
# 17 Batch accuracy: 1.0 Val accuracy: 0.9732
# 18 Batch accuracy: 1.0 Val accuracy: 0.9726
# 19 Batch accuracy: 0.96 Val accuracy: 0.9742
# 20 Batch accuracy: 1.0 Val accuracy: 0.974
# 21 Batch accuracy: 1.0 Val accuracy: 0.9742
# 22 Batch accuracy: 0.98 Val accuracy: 0.9758
# 23 Batch accuracy: 0.98 Val accuracy: 0.9756
# 24 Batch accuracy: 1.0 Val accuracy: 0.9754
# 25 Batch accuracy: 0.96 Val accuracy: 0.9756
# 26 Batch accuracy: 0.94 Val accuracy: 0.976
# 27 Batch accuracy: 1.0 Val accuracy: 0.9762
# 28 Batch accuracy: 1.0 Val accuracy: 0.9764
# 29 Batch accuracy: 1.0 Val accuracy: 0.9764
# 30 Batch accuracy: 1.0 Val accuracy: 0.978
# 31 Batch accuracy: 1.0 Val accuracy: 0.978
# 32 Batch accuracy: 1.0 Val accuracy: 0.9776
# 33 Batch accuracy: 1.0 Val accuracy: 0.9788
# 34 Batch accuracy: 1.0 Val accuracy: 0.979
# 35 Batch accuracy: 1.0 Val accuracy: 0.979
# 36 Batch accuracy: 1.0 Val accuracy: 0.9792
# 37 Batch accuracy: 0.98 Val accuracy: 0.9786
# 38 Batch accuracy: 1.0 Val accuracy: 0.9788
# 39 Batch accuracy: 1.0 Val accuracy: 0.9784

# %%
# restore saved model
with tf.Session() as sess:
    saver.restore(sess, "./my_model_final_v1.ckpt") # or better, use save_path
    X_new_scaled = X_test[:20]
    Z = logits.eval(feed_dict={X: X_new_scaled})
    y_pred = np.argmax(Z, axis=1)
# Out:
# INFO:tensorflow:Restoring parameters from ./my_model_final_v1.ckpt

# %%
print("Predicted classes:", y_pred)
print("Actual classes:   ", y_test[:20])
# Out:
# Predicted classes: [7 2 1 0 4 1 4 9 6 9 0 6 9 0 1 5 9 7 3 4]
# Actual classes:    [7 2 1 0 4 1 4 9 5 9 0 6 9 0 1 5 9 7 3 4]

# %% [markdown]
# ### V2:
# -  same construction and execution phase steps apply
# -  only difference is using tf.layers.dense func to build neuron layer

# %%
n_inputs = 28*28  # MNIST
n_hidden1 = 300
n_hidden2 = 100
n_outputs = 10

# %%
tf.reset_default_graph()

X = tf.placeholder(tf.float32, shape=(None, n_inputs), name="X")
y = tf.placeholder(tf.int32, shape=(None), name="y")

# %%
with tf.name_scope("dnn"):
    hidden1 = tf.layers.dense(X, n_hidden1, name="hidden1",
                              activation=tf.nn.relu)
    hidden2 = tf.layers.dense(hidden1, n_hidden2, name="hidden2",
                              activation=tf.nn.relu)
    logits = tf.layers.dense(hidden2, n_outputs, name="outputs")
    y_proba = tf.nn.softmax(logits)

# %%
with tf.name_scope("loss"):
    xentropy = tf.nn.sparse_softmax_cross_entropy_with_logits(labels=y, logits=logits)
    loss = tf.reduce_mean(xentropy, name="loss")

# %%
learning_rate = 0.01

with tf.name_scope("train"):
    optimizer = tf.train.GradientDescentOptimizer(learning_rate)
    training_op = optimizer.minimize(loss)

# %%
with tf.name_scope("eval"):
    correct = tf.nn.in_top_k(logits, y, 1)
    accuracy = tf.reduce_mean(tf.cast(correct, tf.float32))

# %%
init = tf.global_variables_initializer()
saver = tf.train.Saver()

# %%
n_epochs = 20
n_batches = 50

with tf.Session() as sess:
    init.run()
    for epoch in range(n_epochs):
        for X_batch, y_batch in shuffle_batch(X_train, y_train, batch_size):
            sess.run(training_op, feed_dict={X: X_batch, y: y_batch})
        acc_batch = accuracy.eval(feed_dict={X: X_batch, y: y_batch})
        acc_valid = accuracy.eval(feed_dict={X: X_valid, y: y_valid})
        print(epoch, "Batch accuracy:", acc_batch, "Validation accuracy:", acc_valid)

    save_path = saver.save(sess, "./my_model_final_v2.ckpt")
# Out:
# 0 Batch accuracy: 0.9 Validation accuracy: 0.9036
# 1 Batch accuracy: 0.9 Validation accuracy: 0.9222
# 2 Batch accuracy: 0.9 Validation accuracy: 0.9372
# 3 Batch accuracy: 0.94 Validation accuracy: 0.9428
# 4 Batch accuracy: 0.94 Validation accuracy: 0.9478
# 5 Batch accuracy: 0.96 Validation accuracy: 0.9518
# 6 Batch accuracy: 0.96 Validation accuracy: 0.9566
# 7 Batch accuracy: 0.94 Validation accuracy: 0.958
# 8 Batch accuracy: 0.94 Validation accuracy: 0.9598
# 9 Batch accuracy: 0.96 Validation accuracy: 0.9622
# 10 Batch accuracy: 0.98 Validation accuracy: 0.965
# 11 Batch accuracy: 0.92 Validation accuracy: 0.9674
# 12 Batch accuracy: 1.0 Validation accuracy: 0.9688
# 13 Batch accuracy: 0.94 Validation accuracy: 0.9682
# 14 Batch accuracy: 0.98 Validation accuracy: 0.9694
# 15 Batch accuracy: 0.96 Validation accuracy: 0.9702
# 16 Batch accuracy: 0.98 Validation accuracy: 0.9714
# 17 Batch accuracy: 1.0 Validation accuracy: 0.9716
# 18 Batch accuracy: 1.0 Validation accuracy: 0.9714
# 19 Batch accuracy: 1.0 Validation accuracy: 0.9734

# %% [markdown]
# ### additional exercises:
#
# https://github.com/ageron/handson-ml/blob/master/10_introduction_to_artificial_neural_networks.ipynb
#
# 1. Draw an ANN using the original artificial neurons (like the ones in Figure 10-3) that computes A ⊕ B (where ⊕ represents the XOR operation). Hint: A ⊕ B = (A ∧ ¬ B) ∨ (¬ A ∧ B).
# 2. Why is it generally preferable to use a Logistic Regression classifier rather than a classical Perceptron (i.e., a single layer of linear threshold units trained using the Perceptron training algorithm)? How can you tweak a Perceptron to make it equivalent to a Logistic Regression classifier?
# 3. Why was the logistic activation function a key ingredient in training the first MLPs?
# 4. Name three popular activation functions. Can you draw them?
# 5. Suppose you have an MLP composed of one input layer with 10 passthrough neurons, followed by one hidden layer with 50 artificial neurons, and finally one output layer with 3 artificial neurons. All artificial neurons use the ReLU activa‐ tion function. • What is the shape of the input matrix X? • What about the shape of the hidden layer’s weight vector Wh, and the shape of its bias vector bh? • What is the shape of the output layer’s weight vector Wo, and its bias vector bo? • What is the shape of the network’s output matrix Y? • Write the equation that computes the network’s output matrix Y as a function of X, Wh, bh, Wo and bo.
# 6. How many neurons do you need in the output layer if you want to classify email into spam or ham? What activation function should you use in the output layer? If instead you want to tackle MNIST, how many neurons do you need in the out‐ put layer, using what activation function? Answer the same questions for getting your network to predict housing prices as in Chapter 2.
# 7. What is backpropagation and how does it work? What is the difference between backpropagation and reverse-mode autodiff?
# 8. Can you list all the hyperparameters you can tweak in an MLP? If the MLP over‐ fits the training data, how could you tweak these hyperparameters to try to solve the problem?
# 9. Train a deep MLP on the MNIST dataset and see if you can get over 98% preci‐ sion. Just like in the last exercise of Chapter 9, try adding all the bells and whistles (i.e., save checkpoints, restore the last checkpoint in case of an interruption, add summaries, plot learning curves using TensorBoard, and so on).

# %% [markdown]
# ### grp
